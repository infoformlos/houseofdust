# %%
import time
from random import choice

material = ['SAND', 'DUST', 'LEAVES', 'PAPER', 'TIN', 'ROOTS', 'BRICK',
            'STONE', 'DISCARDED CLOTHING', 'GLASS', 'STEEL', 'PLASTIC',
            'MUD', 'BROKEN DISHES', 'WOOD', 'STRAW', 'WEEDS']

location = ['IN A GREEN, MOSSY TERRAIN', 'IN AN OVERPOPULATED AREA',
            'BY THE SEA', 'BY AN ABANDONED LAKE', 'IN A DESERTED FACTORY',
            'IN DENSE WOODS', 'IN JAPAN', 'AMONG SMALL HILLS',
            'IN SOUTHERN FRANCE', 'AMONG HIGH MOUNTAINS', 'ON AN ISLAND',
            'IN A COLD, WINDY CLIMATE',
            'IN A PLACE WITH BOTH HEAVY RAIN AND BRIGHT SUN',
            'IN A DESERTED AIRPORT', 'IN A HOT CLIMATE',
            'INSIDE A MOUNTAIN', 'ON THE SEA', 'IN MICHIGAN',
            'IN HEAVY JUNGLE UNDERGROWTH', 'BY A RIVER',
            'AMONG OTHER HOUSES', 'IN A DESERTED CHURCH',
            'IN A METROPOLIS', 'UNDERWATER']

light_source = ['CANDLES', 'ALL AVAILABLE LIGHTING', 'ELECTRICITY',
                'NATURAL LIGHT']


inhabitants = ['PEOPLE WHO SLEEP VERY LITTLE', 'VEGETARIANS', 'HORSES AND BIRDS',
               'PEOPLE SPEAKING MANY LANGUAGES WEARING LITTLE OR NO CLOTHING',
               'ALL RACES OF MEN REPRESENTED WEARING PREDOMINANTLY RED CLOTHING',
               'CHILDREN AND OLD PEOPLE', 'VARIOUS BIRDS AND FISH', 'LOVERS',
               'PEOPLE WHO ENJOY EATING TOGETHER', 'PEOPLE WHO EAT A GREAT DEAL',
               'COLLECTORS OF ALL TYPES', 'FRIENDS AND ENEMIES',
               'PEOPLE WHO SLEEP ALMOST ALL THE TIME', 'VERY TALL PEOPLE',
               'AMERICAN INDIANS', 'LITTLE BOYS',
               'PEOPLE FROM MANY WALKS OF LIFE',
               'NEGROS WEARING ALL COLORS', 'FRIENDS',
               'FRENCH AND GERMAN SPEAKING PEOPLE',
               'FISHERMEN AND FAMILIES', 'PEOPLE WHO LOVE TO READ']

for i in range(60):
  print('')
  print('A HOUSE OF ' + choice(material))
  print('      ' + choice(location))
  print('            USING ' + choice(light_source))
  print('                  INHABITED BY ' + choice(inhabitants))
  print('')
  time.sleep(1)
# Out:
# A HOUSE OF PLASTIC
#       IN HEAVY JUNGLE UNDERGROWTH
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO SLEEP VERY LITTLE
#
#
# A HOUSE OF ROOTS
#       AMONG HIGH MOUNTAINS
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF PAPER
#       ON THE SEA
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY PEOPLE WHO SLEEP ALMOST ALL THE TIME
#
#
# A HOUSE OF SAND
#       IN AN OVERPOPULATED AREA
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY FRIENDS AND ENEMIES
#
#
# A HOUSE OF WOOD
#       IN A DESERTED CHURCH
#             USING ELECTRICITY
#                   INHABITED BY VERY TALL PEOPLE
#
#
# A HOUSE OF DUST
#       IN A GREEN, MOSSY TERRAIN
#             USING NATURAL LIGHT
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF DUST
#       IN DENSE WOODS
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY VEGETARIANS
#
#
# A HOUSE OF STONE
#       AMONG HIGH MOUNTAINS
#             USING NATURAL LIGHT
#                   INHABITED BY VEGETARIANS
#
#
# A HOUSE OF DISCARDED CLOTHING
#       IN MICHIGAN
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE FROM MANY WALKS OF LIFE
#
#
# A HOUSE OF ROOTS
#       INSIDE A MOUNTAIN
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO ENJOY EATING TOGETHER
#
#
# A HOUSE OF DUST
#       INSIDE A MOUNTAIN
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE WHO SLEEP ALMOST ALL THE TIME
#
#
# A HOUSE OF DUST
#       IN HEAVY JUNGLE UNDERGROWTH
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO LOVE TO READ
#
#
# A HOUSE OF GLASS
#       IN A PLACE WITH BOTH HEAVY RAIN AND BRIGHT SUN
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO ENJOY EATING TOGETHER
#
#
# A HOUSE OF DUST
#       AMONG HIGH MOUNTAINS
#             USING CANDLES
#                   INHABITED BY PEOPLE WHO LOVE TO READ
#
#
# A HOUSE OF WEEDS
#       IN MICHIGAN
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE FROM MANY WALKS OF LIFE
#
#
# A HOUSE OF PAPER
#       ON THE SEA
#             USING CANDLES
#                   INHABITED BY FRENCH AND GERMAN SPEAKING PEOPLE
#
#
# A HOUSE OF MUD
#       ON AN ISLAND
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF SAND
#       IN A GREEN, MOSSY TERRAIN
#             USING ELECTRICITY
#                   INHABITED BY LITTLE BOYS
#
#
# A HOUSE OF STONE
#       IN A HOT CLIMATE
#             USING NATURAL LIGHT
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF DISCARDED CLOTHING
#       BY A RIVER
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE FROM MANY WALKS OF LIFE
#
#
# A HOUSE OF LEAVES
#       ON THE SEA
#             USING NATURAL LIGHT
#                   INHABITED BY CHILDREN AND OLD PEOPLE
#
#
# A HOUSE OF GLASS
#       IN A COLD, WINDY CLIMATE
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY FRENCH AND GERMAN SPEAKING PEOPLE
#
#
# A HOUSE OF PAPER
#       IN A COLD, WINDY CLIMATE
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO ENJOY EATING TOGETHER
#
#
# A HOUSE OF GLASS
#       IN A COLD, WINDY CLIMATE
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY PEOPLE WHO LOVE TO READ
#
#
# A HOUSE OF MUD
#       BY THE SEA
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE SPEAKING MANY LANGUAGES WEARING LITTLE OR NO CLOTHING
#
#
# A HOUSE OF BROKEN DISHES
#       IN A METROPOLIS
#             USING ELECTRICITY
#                   INHABITED BY FRENCH AND GERMAN SPEAKING PEOPLE
#
#
# A HOUSE OF STEEL
#       IN A METROPOLIS
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE WHO ENJOY EATING TOGETHER
#
#
# A HOUSE OF STRAW
#       IN A DESERTED FACTORY
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY COLLECTORS OF ALL TYPES
#
#
# A HOUSE OF WOOD
#       IN A METROPOLIS
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO EAT A GREAT DEAL
#
#
# A HOUSE OF STRAW
#       BY AN ABANDONED LAKE
#             USING ELECTRICITY
#                   INHABITED BY HORSES AND BIRDS
#
#
# A HOUSE OF BRICK
#       IN AN OVERPOPULATED AREA
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY ALL RACES OF MEN REPRESENTED WEARING PREDOMINANTLY RED CLOTHING
#
#
# A HOUSE OF LEAVES
#       IN A DESERTED AIRPORT
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY VARIOUS BIRDS AND FISH
#
#
# A HOUSE OF WEEDS
#       ON THE SEA
#             USING ELECTRICITY
#                   INHABITED BY FRIENDS
#
#
# A HOUSE OF PAPER
#       IN A COLD, WINDY CLIMATE
#             USING ELECTRICITY
#                   INHABITED BY VERY TALL PEOPLE
#
#
# A HOUSE OF STEEL
#       UNDERWATER
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY FRIENDS AND ENEMIES
#
#
# A HOUSE OF ROOTS
#       UNDERWATER
#             USING CANDLES
#                   INHABITED BY NEGROS WEARING ALL COLORS
#
#
# A HOUSE OF STEEL
#       BY A RIVER
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY PEOPLE WHO SLEEP ALMOST ALL THE TIME
#
#
# A HOUSE OF WEEDS
#       UNDERWATER
#             USING ELECTRICITY
#                   INHABITED BY AMERICAN INDIANS
#
#
# A HOUSE OF STONE
#       AMONG HIGH MOUNTAINS
#             USING ELECTRICITY
#                   INHABITED BY VERY TALL PEOPLE
#
#
# A HOUSE OF PAPER
#       AMONG OTHER HOUSES
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY PEOPLE WHO SLEEP VERY LITTLE
#
#
# A HOUSE OF DUST
#       UNDERWATER
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE WHO SLEEP VERY LITTLE
#
#
# A HOUSE OF DUST
#       AMONG SMALL HILLS
#             USING ELECTRICITY
#                   INHABITED BY VEGETARIANS
#
#
# A HOUSE OF WOOD
#       BY THE SEA
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE SPEAKING MANY LANGUAGES WEARING LITTLE OR NO CLOTHING
#
#
# A HOUSE OF BRICK
#       IN A COLD, WINDY CLIMATE
#             USING NATURAL LIGHT
#                   INHABITED BY HORSES AND BIRDS
#
#
# A HOUSE OF PAPER
#       IN A HOT CLIMATE
#             USING NATURAL LIGHT
#                   INHABITED BY HORSES AND BIRDS
#
#
# A HOUSE OF ROOTS
#       IN A COLD, WINDY CLIMATE
#             USING ELECTRICITY
#                   INHABITED BY FRENCH AND GERMAN SPEAKING PEOPLE
#
#
# A HOUSE OF STRAW
#       AMONG HIGH MOUNTAINS
#             USING NATURAL LIGHT
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF WEEDS
#       IN A DESERTED FACTORY
#             USING ELECTRICITY
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF DUST
#       INSIDE A MOUNTAIN
#             USING CANDLES
#                   INHABITED BY PEOPLE FROM MANY WALKS OF LIFE
#
#
# A HOUSE OF MUD
#       IN A DESERTED FACTORY
#             USING ELECTRICITY
#                   INHABITED BY FRIENDS
#
#
# A HOUSE OF DISCARDED CLOTHING
#       IN DENSE WOODS
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF GLASS
#       ON AN ISLAND
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE WHO EAT A GREAT DEAL
#
#
# A HOUSE OF ROOTS
#       BY AN ABANDONED LAKE
#             USING CANDLES
#                   INHABITED BY AMERICAN INDIANS
#
#
# A HOUSE OF STEEL
#       IN HEAVY JUNGLE UNDERGROWTH
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE WHO EAT A GREAT DEAL
#
#
# A HOUSE OF GLASS
#       IN A METROPOLIS
#             USING CANDLES
#                   INHABITED BY COLLECTORS OF ALL TYPES
#
#
# A HOUSE OF GLASS
#       AMONG SMALL HILLS
#             USING NATURAL LIGHT
#                   INHABITED BY FRENCH AND GERMAN SPEAKING PEOPLE
#
#
# A HOUSE OF STRAW
#       INSIDE A MOUNTAIN
#             USING ALL AVAILABLE LIGHTING
#                   INHABITED BY VEGETARIANS
#
#
# A HOUSE OF LEAVES
#       IN A DESERTED CHURCH
#             USING ELECTRICITY
#                   INHABITED BY PEOPLE FROM MANY WALKS OF LIFE
#
#
# A HOUSE OF WEEDS
#       IN JAPAN
#             USING ELECTRICITY
#                   INHABITED BY LOVERS
#
#
# A HOUSE OF PAPER
#       IN A COLD, WINDY CLIMATE
#             USING NATURAL LIGHT
#                   INHABITED BY PEOPLE WHO SLEEP VERY LITTLE

# %% [markdown]
# # Neuer Abschnitt
